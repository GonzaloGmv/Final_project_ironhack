# %% [markdown]
# # Scaler

# %% [markdown]
# ### Importar las librerias necesarias

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler ,MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('regression_data_clean.csv')
df.head()
# Out:
#    bedrooms  bathrooms  floors  waterfront  view  grade  sqft_above      lat  \
# 0         3       1.00     1.0           0     0      7        1180  47.5112
# 1         3       2.25     2.0           0     0      7        2170  47.7210
# 2         2       1.00     1.0           0     0      6         770  47.7379
# 3         4       3.00     1.0           0     0      7        1050  47.5208
# 4         3       2.00     1.0           0     0      8        1680  47.6168
#
#     price  sqft_total
# 0  221900        1340
# 1  538000        2090
# 2  180000        2720
# 3  604000        2270
# 4  510000        1800

# %% [markdown]
# El primer paso es separar los datos de train y test de nuestra variable dependiente de las independientes

# %%
X = df.drop('price',axis=1)
y = df['price']

X.head()
# Out:
#    bedrooms  bathrooms  floors  waterfront  view  grade  sqft_above      lat  \
# 0         3       1.00     1.0           0     0      7        1180  47.5112
# 1         3       2.25     2.0           0     0      7        2170  47.7210
# 2         2       1.00     1.0           0     0      6         770  47.7379
# 3         4       3.00     1.0           0     0      7        1050  47.5208
# 4         3       2.00     1.0           0     0      8        1680  47.6168
#
#    sqft_total
# 0        1340
# 1        2090
# 2        2720
# 3        2270
# 4        1800
